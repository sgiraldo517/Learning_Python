# %% [markdown]
# # Intermediate Python
# ----
# ## Matplotlib
# ----
# Matplotlib is one of the Python packages that allow us to do **Data Visualization**. Data visualization is veru important for data analysis. It help us to:
# - Explore data
# - Report insights
#
# ### Basic plots with Matplotlib

# %%
# First we will need to import pyplot (a subpackage from Matplotlib)
import matplotlib.pyplot as plt

year = [1950, 1970, 1990, 2012]
pop = [2.519, 3.692, 5.263, 6.972]

# To make a line plot: 
plt.plot(year, pop)
    ## Note: the first argument corresponds to the horizontal axis (x-axis) and the sendo to the vertical one (y-axis) 
    
# To display a plot you will need the show argument: 
plt.show()

# %% [markdown]
# When you have a time scale along the horizontal axis, the line plot is your friend. But in many other cases, when you're trying to assess if there's a correlation between two variables, for example, the scatter plot is the better choice. Below is an example of how to build a scatter plot.

# %%
# To draw a scatter plot we will use the following code (This type of plot will only display the individual data points):
plt.scatter(year, pop)
plt.show()

# Something usefull to add to the scatter plot is the size of the dots to better represent the data shown
import numpy as np
np_pop = np.array(pop)
np_pop = np_pop * 30

plt.scatter(year, pop, s=np_pop)
plt.show()
    ## Note: sometimes it is also useful to convert the axis into a logarithmic scale. use the following code: 
    ## plt.xscale('log')

# %% [markdown]
# ### Histogram
# It can help us to get an idea about the distribution of the variables.

# %%
import matplotlib.pyplot as plt

# To check the documentation fot the histogram 
## help(plt.hist)

values = [0,0.6,1.4,1.6,2.2,2.5,2.6,3.2,3.5,3.9,4.2,6]

# To plot a histogram
plt.hist(values, bins=3)
    ## Note: If the number od bins is not specified, python will set 10 as default.

plt.show()    
# plt.clf() deletes a plot

# %% [markdown]
# ### Customization

# %%
# Add more data
year = [1800, 1850, 1900] + year
pop = [2.538, 2.57, 2.62] + pop

# To change the color you will add the c parameter and to change the oppacity you will set the alpha parameter
plt.plot(year, pop, c='g', alpha = 0.5)

# Add labels
plt.xlabel('Year')
plt.ylabel('Population')

# Add title
plt.title('World Population Projections')

# To change the scale in the Y-axis
plt.yticks([0,2,4,6,8])

# We can also modify the displayed names on the ticks (the lenght of both arrays need to be the same)
plt.yticks([0,2,4,6,8],
            ['0', '2B', '4B', '6B', '8B'])

    ## Note: to modify the x ticks we will use plt.xticks()
    
# To add a grid 
plt.grid(True)

## NOTE: all customizations need to be added before the show function
plt.show()

# %% [markdown]
# ## Dictionaries and Pandas
# ----
# ### Dictionaries
# Allow us to store information in an alternative way to list so that it is easier to identify the corresponding values. To build a dictionary you will use **{}** and the data will be organized as follows:
#
# `dictionary = {"keyword1":value, "keyword2":value, "keyword3":value]`

# %%
# Example of a dictionary
world = {"afghanistan":30.55, "albania": 2.77, "algeria":39.21}

# To access the value of an element you pass the key of the corresponding value in []
world["albania"]
# Out:
# 2.77

# %%
# Comparison between index method vs dictionaries

countries = ['spain', 'france', 'germany', 'norway']
capitals = ['madrid', 'paris', 'berlin', 'oslo']

## INDEX METHOD
# Get index of 'germany': ind_ger
ind_ger = countries.index("germany")

# Use ind_ger to print out capital of Germany
print(capitals[ind_ger])

europe = {'spain':'madrid', 'france': 'paris', 'germany':'berlin', 'norway': 'oslo'}

## DICTIONARY METHOD
# Print out the keys in europe
print(europe.keys())

# Print out value that belongs to key 'norway'
print(europe['norway'])
# Out:
# berlin
# dict_keys(['spain', 'france', 'germany', 'norway'])
# oslo

# %% [markdown]
# #### Characteristics of the keys
# - The keys in a dictionary need to be **unique**: If the keys are duplicated, only the last value specified will be included taken into account
# - Keys have to be immutable objects: the content of the immutable objects can not be changed after they are created
#      >**Note**  int, strings, floats and booleans are immutable objects. Lists are not. This means that lists can not be set as keys for a dictionary

# %%
# Add an element to a dictionary 
world["sealand"] = 0.000027
print(world)

# To check if a key is included in a dictionary
print('sealand' in world)

# Update a value
world["sealand"] = 0.000028
print(world)

# To delete an element from a dictionary 
del(world["sealand"])
print(world)
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21, 'sealand': 2.7e-05}
# True
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21, 'sealand': 2.8e-05}
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21}

# %% [markdown]
# #### Lists vs. Dictionaries
# |                List                 |               Dictionary            |
# | ----------------------------------- | ----------------------------------- |
# | Select, update, and remove with [ ] | Select, update, and remove with { } |
# | Indexed by range of numbers         | Indexed by unique keys              |
# | Collection of values - orders matters, for selecting entire subsets | Lookup table with unique keys |

# %% [markdown]
# #### Dictionary of dictionaries

# %%
# Dictionary of dictionaries
europe = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }


# Print out the capital of France
print(europe['france']['capital'])

# Create sub-dictionary data
data = {'capital': 'rome', 'population':59.83}

# Add data to europe under key 'italy'
europe["italy"] = data

# Print europe
print(europe)

# %% [markdown]
# ### Pandas
# High level data maniputalion tool built on the Numpy package. It allows to store the tabular data in an element called a **Dataframe**

# %% [markdown]
# #### Creating Dataframes from dictionaries
# Having the following dictionary:
# ```
# dict = {
#     "country": ["Brazil", "Russia", "India", "China", "South Africa"],
#     "capital": ["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
#     "area": [8.516, 17.10, 3.286, 9.597, 1.221],
#     "population": [200.4, 143.5, 1252, 1347, 52.98] }
# ```
# - Keys will be the **column** labels
# - Values will be the **data**, column by column

# %%
# Create the dict
dict = { 
    "country": ["Brazil", "Russia", "India", "China", "South Africa"],
    "capital": ["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
    "area": [8.516, 17.10, 3.286, 9.597, 1.221],
    "population": [200.4, 143.5, 1252, 1347, 52.98] }

# Import Pandas
import pandas as pd

# Convert the dict into a pandas Dataframe
brics = pd.DataFrame(dict)
print(brics)
print(type(brics))

# To update the authomatic indexes assigned by pandas
brics.index = ['BR','RU','IN','CH','SA']
print(brics)
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia   8.516      200.40
# 1        Russia     Moscow  17.100      143.50
# 2         India  New Delhi   3.286     1252.00
# 3         China    Beijing   9.597     1347.00
# 4  South Africa   Pretoria   1.221       52.98
# <class 'pandas.core.frame.DataFrame'>
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1347.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
# Pre-defined lists
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

# Import pandas as pd
import pandas as pd

# Create dictionary my_dict with three key:value pairs: my_dict
my_dict = { 
    "country": names,
    "drives_right": dr,
    "cars_per_cap": cpc
}

# Build a DataFrame cars from my_dict: cars
cars = pd.DataFrame(my_dict) 

# Print cars
print(cars)

# Definition of row_labels
row_labels = ['US', 'AUS', 'JPN', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index = row_labels

# Print cars again
print(cars)
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45
#            country  drives_right  cars_per_cap
# US   United States          True           809
# AUS      Australia         False           731
# JPN          Japan         False           588
# IN           India         False            18
# RU          Russia          True           200
# MOR        Morocco          True            70
# EG           Egypt          True            45

# %% [markdown]
# #### Import data from an external source
# Frequently, we will need to import data from CSV files. To do it we will need the following code:
#
# `database = pd.read_csv("path/to/file.csv")`
#
#   >**Note:** if necesarry you can specify the column that correspond to the indexes by adding the parameter: `index_col= 0`

# %% [markdown]
# #### Index and Select data from a Dataframe
# There are 2 methods to select data from dataframes with pandas:
# 1. **Square brackets:**
#
#     To select a column from a dataframe with square brackets you only need to write the name of the Dataframe and the name of the column you want to select in square brackets `dataframe['column']`
#       >**Note:** when we use a single [], the column will be saves as a pandas series. To save the data as a dataframe we should use [[ ]] `dataframe[['column1','column2']]`
#
#     To select rows we nees to use the slice method `dataframe[1:4]`. The previous code will select rows from the 2nd to the 5th row.
#
#     *Limitations: the square brackets method will only allow us to select either columns or rows, not a combiantion of both*
#
# 2. **Loc and Iloc:** allow us to create both columns and rows of a dataframe
#
#     - **loc:**  is label-based, which means that you have to specify rows and columns based on their row and column labels.
#
#         Example:
#
#         - One row and one column `cars.loc['IN', 'cars_per_cap']`
#         - Multiple rows and one column `cars.loc[['IN', 'RU'], 'cars_per_cap']`
#         - Multiple rows and multiple columns `cars.loc[['IN', 'RU'], ['cars_per_cap', 'country']]`
#         - Select all rows and one column `cars.loc[:, 'country']`
#         - Select all rows and multiple columns `cars.loc[:, ['country','drives_right']]`
#
#     - **iloc:** is integer index based, so you have to specify rows and columns by their integer index.
#
#         Example:
#
#         - One row and one column `cars.iloc[3, 0]`
#         - Multiple rows and one column `cars.iloc[[3, 4], 0]`
#         - Multiple rows and multiple columns `cars.iloc[[3, 4], [0, 1]]`
#         - Select all rows and one column `cars.iloc[:, 1]`
#         - Select all rows and multiple columns `cars.iloc[:, [1, 2]]`
#
#     >**Note:** To print a single column and all rows as a Dataframe use: `cars.iloc[:,[2]]`

# %% [markdown]
# ## Logic, Control Flow and Filtering
# ----

# %% [markdown]
# ### Comparison Operators
# Operator that can tell how 2 Python values relate, and result in a boolean.
# >**Note:** Python can not tell how 2 objects with different data types relate. *Exceptions: Float and Integers, **NympyArrys** and Integers*
#
# #### Comparators
#
# | Comparator | Meaning |
# | ------ | ---- |
# | < | Strictly less than|
# | <= | Less than or equal |
# | > | Strictly greater than |
# | == | Equal |
# | != | Not equal |

# %%
# To check if two Python values, or variables, are equal you can use ==. To check for inequality, you need !=

# Comparison of booleans
print(True == False)

# Comparison of integers
print((-5*15) != 75)

# Comparison of strings
print("pyscript" == "PyScript")

# Compare a boolean with an integer
print(True == 1)
# Out:
# False
# True
# False
# True

# %%
# Greater and less than

# Comparison of integers
x = -3 * 6
print(x >= -10)

# Comparison of strings
y = "test"
print("test" <= y)

# Comparison of booleans
print(True > False)
# Out:
# False
# True
# True

# %%
# Compare arrays

# Create arrays
import numpy as np
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# my_house greater than or equal to 18
print(my_house >= 18)

# my_house less than your_house
print (my_house <= your_house)
# Out:
# [ True  True False False]
# [False  True  True False]

# %% [markdown]
# ### Boolean Operations
# The 3 most common operators are:
# - **and:** Takes 2 booleans and returns True only if both the booleans themselves are True
# - **or:** At least one of the booleans used should be True
# - **not:** It simply negates the boolean value you use it on

# %%
# and, or, not

# Define variables
my_kitchen = 18.0
your_kitchen = 14.0

# my_kitchen bigger than 10 and smaller than 18?
print(my_kitchen > 10 and my_kitchen < 18)

# my_kitchen smaller than 14 or bigger than 17?
print(my_kitchen < 14 or my_kitchen > 17)

# Double my_kitchen smaller than triple your_kitchen?
print(my_kitchen*2 < your_kitchen*3)

# %% [markdown]
# #### Boolean Operators in Numpy arrays
# For Numpy arrays we need to use the following methods as the regular boolean operators will generate an error. This methods are performed element-wise:
# - **logical_and()**
# - **logical_or()**
# - **logical_not()**

# %%
# Boolean operators with NumPy

# Create arrays
import numpy as np
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# my_house greater than 18.5 or smaller than 10
print(np.logical_or(my_house > 18.5, my_house < 10))

# Both my_house and your_house smaller than 11
print(np.logical_and(my_house <11, your_house < 11))

# %% [markdown]
# ### Conditional Statements: if, elif else
#
# ```
# if condition1 :
#     expression
# elif condition2 :
#     expression
# else :
#     expression
# ```
#
# - The **if** conditional will run a piece of code whenever a condition is **True**.
#
# >**Note:** the expression segment of the if structure can contain more than a single piece of code to be executed
#
# - To specify another possible condition an piece of code to be executed we will use **elif**.
# - To execute a code when **none** of the specified conditions are **true** we will use **else**.
#
# >**Note:** As soon as Python bumps into a condition that is true, it executes the corresponding code and then stop running.

# %%
area = 10.0
if(area < 9) :
    print("small")
elif(area < 12) :
    print("medium")
else :
    print("large")
# Out:
# medium

# %%
# Define variables
room = "bed"
area = 14.0

# if-elif-else construct for room
if room == "kit" :
    print("looking around in the kitchen.")
elif room == "bed":
    print("looking around in the bedroom.")
else :
    print("looking around elsewhere.")

# if-elif-else construct for area
if area > 15 :
    print("big place!")
elif area > 10 :
    print("medium size, nice!")
else :
    print("pretty small.")
# Out:
# looking around in the bedroom.
# medium size, nice!

# %% [markdown]
# ### Filtering pandas DataFrames
# To filter data in a Pandas Dataframe we will need to follow this steps:
# 1. We will need to extract as a Series the column by we want to filter.
# 2. Perform a comparison on the recently created column.
# 3. Use the column to index the DataFrame

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('Datasets/cars.csv', index_col = 0)

# Extract drives_right column as Series: dr
dr = cars['drives_right']

# Use dr to subset cars: sel
sel = cars[dr]

# Print sel
print(sel)
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %% [markdown]
# The code in the previous example worked fine, but you actually unnecessarily created a new variable dr. You can achieve the same result without this intermediate variable. Put the code that computes dr straight into the square brackets that select observations from cars.

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('Datasets/cars.csv', index_col = 0)

# Convert code to a one-liner
sel = cars[cars['drives_right']]

# Print sel
print(sel)
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %% [markdown]
# You can also use `np.logical_and()`, `np.logical_or()` and `np.logical_not()` on Pandas Series to do more advanced filtering operations. Please see the following example:

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('Datasets/cars.csv', index_col = 0)

# Import numpy, you'll need this
import numpy as np

# Create medium: observations with cars_per_cap between 100 and 500
cpc = cars['cars_per_cap']
between = np.logical_and(cpc > 100, cpc < 500)
medium = cars[between]

# Print medium
print(medium)
# Out:
#     cars_per_cap country  drives_right
# RU           200  Russia          True

# %% [markdown]
# ## Loops
# ----

# %% [markdown]
# ### While loop
# The while loop is like a repeated if statement. The code is executed over and over again, as long as the condition is `True`
# ```
# while condition :
#     expression
# ````

# %%
# Example 1 
# The following code will only have 3 printouts
x = 1
while x < 4 :
    print(x)
    x = x + 1
    
print("-----------------")

# Example 2
# Initialize offset
offset = 8

# Code the while loop
while offset != 0 :
    print("correcting...")
    offset = offset - 1
    print(offset)
    
print("-----------------")
    
# Example 3: add an if - else into the while
# Initialize offset
offset = -6

# Code the while loop
while offset != 0 :
    print("correcting...")
    if offset > 0 :
      offset = offset - 1
    else : 
      offset = offset + 1
    print(offset)
# Out:
# 1
# 2
# 3
# -----------------
# correcting...
# 7
# correcting...
# 6
# correcting...
# 5
# correcting...
# 4
# correcting...
# 3
# correcting...
# 2
# correcting...
# 1
# correcting...
# 0
# -----------------
# correcting...
# -5
# correcting...
# -4
# correcting...
# -3
# correcting...
# -2
# correcting...
# -1
# correcting...
# 0

# %% [markdown]
# ### for loop
# The structure of the for loop is the following:
# ```
# for variable in sequeance :
#     expression
# ```
# The code above can be read as: *"for each variable, in a sequence, execute the expressions"*

# %%
# Example 1 
fam = [1.73, 1.68, 1.71, 1.89]
for index, height in enumerate(fam) :
    print("index " + str(index) + ": " + str(height))

print("---------------")

    # Enumerate function: Enumerate() method adds a counter to an iterable and returns it in a form of enumerating object. This enumerated object can then be used directly for loops or converted into a list of tuples using the list() function.
        # Syntax: enumerate(iterable, start=0) 
            # iterable: any object that supports iteration
            # Start:  the index value from which the counter is to be started, by default it is 0 
            
fam = [1.73, 1.68, 1.71, 1.89]
print (list(enumerate(fam, 0)))
print (list(enumerate(fam, 2)))

print("---------------")

# Example 2: we can also iterate over every character of a string
for c in "family":
    print(c.capitalize())
print("---------------")

#Example 3: Loop over list of lists
# house list of lists
house = [["hallway", 11.25], 
         ["kitchen", 18.0], 
         ["living room", 20.0], 
         ["bedroom", 10.75], 
         ["bathroom", 9.50]]
         
# Build a for loop from scratch
for room,area in house : 
    print('the ' + room + ' is ' + str(area) + ' sqm')
# Out:
# index 0: 1.73
# index 1: 1.68
# index 2: 1.71
# index 3: 1.89
# ---------------
# [(0, 1.73), (1, 1.68), (2, 1.71), (3, 1.89)]
# [(2, 1.73), (3, 1.68), (4, 1.71), (5, 1.89)]
# ---------------
# F
# A
# M
# I
# L
# Y
# ---------------
# the hallway is 11.25 sqm
# the kitchen is 18.0 sqm
# the living room is 20.0 sqm
# the bedroom is 10.75 sqm
# the bathroom is 9.5 sqm

# %% [markdown]
# ### Loop different Data Structures

# %%
# Dictionaries
world = {"afghsnistan":30.55, "albania":2.77, "algeria":39.21}
for key, value in world.items():
    print(key + ":" + str(value))
    
    # Note: dictionaries are not ordered strictly so the for loop will not consider any particular order.

print("------------")

# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw', 'austria':'vienna' }
          
# Iterate over europe
for country,capital in europe.items(): 
    print("The capital of " + country + " is " + capital)

print("------------")

# Numpy Arrays
# 1D Numpy arrays
import numpy as np 
np_height = np.array([1.70, 2.30, 1.68])
for val in np_height : 
    print (val)

print("------------")

# We need to have special care with 2D numpy arrays as the for will not read them correctly. How to go through all elements?  

np_weight = np.array([65.4, 59.2, 88.4]) 
meas = np.array([np_height, np_weight]) 

for val in np.nditer(meas): 
    print(val)

# Final consideration: 
# Dictionaries require a method (items) != Numpy Arrays require a function (nditer)
# Out:
# afghsnistan:30.55
# albania:2.77
# algeria:39.21
# ------------
# The capital of spain is madrid
# The capital of france is paris
# The capital of germany is berlin
# The capital of norway is oslo
# The capital of italy is rome
# The capital of poland is warsaw
# The capital of austria is vienna
# ------------
# 1.7
# 2.3
# 1.68
# ------------
# 1.7
# 2.3
# 1.68
# 65.4
# 59.2
# 88.4

# %%
# Dataframes
import pandas as pd
brics = pd.read_csv("Datasets/brics.csv", index_col = 0) 

# The normal iterative structure will not go through all the dataframe. We need to tell python to iterate over the rows
for val in brics : 
    print(val)

print("------------")

# Iterrows: looks at the dataframe and on each iteration generates the label of the row and then the actual data in the row
for label, row in brics.iterrows():
    print(label)
    print(row)

print("------------")

for label, row in brics.iterrows():
    print(label + ": " + row["capital"])
# Out:
# country
# capital
# area
# population
# ------------
# BR
# country         Brazil
# capital       Brasilia
# area             8.516
# population       200.4
# Name: BR, dtype: object
# RU
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: RU, dtype: object
# IN
# country           India
# capital       New Delhi
# area              3.286
# population       1252.0
# Name: IN, dtype: object
# CH
# country         China
# capital       Beijing
# area            9.597
# population     1357.0
# Name: CH, dtype: object
# SA
# country       South Africa
# capital           Pretoria
# area                 1.221
# population           52.98
# Name: SA, dtype: object
# ------------
# BR: Brasilia
# RU: Moscow
# IN: New Delhi
# CH: Beijing
# SA: Pretoria

# %%
# Add a column to a Dataframe 
for lab, row in brics.iterrows(): 
    brics.loc[lab, "name_length"] = len(row["country"])
brics

    # The previusly stated code does the job but is inefficient
# Out:
#          country    capital    area  population  name_lenght  name_length
# BR        Brazil   Brasilia   8.516      200.40            6          6.0
# RU        Russia     Moscow  17.100      143.50            6          6.0
# IN         India  New Delhi   3.286     1252.00            5          5.0
# CH         China    Beijing   9.597     1357.00            5          5.0
# SA  South Africa   Pretoria   1.221       52.98           12         12.0

# %%
# Apply: if you want to calculate an entire DataFrame column by applying a function on a particular column in an element-wise fashion, is apply().

brics["name_lenght"] = brics["country"].apply(len)
brics
# Out:
#          country    capital    area  population  name_lenght  name_length
# BR        Brazil   Brasilia   8.516      200.40            6          6.0
# RU        Russia     Moscow  17.100      143.50            6          6.0
# IN         India  New Delhi   3.286     1252.00            5          5.0
# CH         China    Beijing   9.597     1357.00            5          5.0
# SA  South Africa   Pretoria   1.221       52.98           12         12.0

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('Datasets/cars.csv', index_col = 0)

# Adapt for loop
for lab, row in cars.iterrows() :
    print(lab + ": " +  str(row["cars_per_cap"]))
    
# Code for loop that adds COUNTRY column
for lab,row in cars.iterrows(): 
    cars.loc[lab, "COUNTRY"] = row["country"].upper()
cars
# Out:
# US: 809
# AUS: 731
# JAP: 588
# IN: 18
# RU: 200
# MOR: 70
# EG: 45
#      cars_per_cap        country  drives_right        COUNTRY
# US            809  United States          True  UNITED STATES
# AUS           731      Australia         False      AUSTRALIA
# JAP           588          Japan         False          JAPAN
# IN             18          India         False          INDIA
# RU            200         Russia          True         RUSSIA
# MOR            70        Morocco          True        MOROCCO
# EG             45          Egypt          True          EGYPT

# %%
# Use .upper
for lab, row in cars.iterrows() :
    cars.loc[lab, "COUNTRY"] = row["country"].upper()
cars
# Out:
#      cars_per_cap        country  drives_right        COUNTRY
# US            809  United States          True  UNITED STATES
# AUS           731      Australia         False      AUSTRALIA
# JAP           588          Japan         False          JAPAN
# IN             18          India         False          INDIA
# RU            200         Russia          True         RUSSIA
# MOR            70        Morocco          True        MOROCCO
# EG             45          Egypt          True          EGYPT

# %% [markdown]
# ## Case Study: Hacker Statistics
# ----

# %% [markdown]
# ### Random float
# To generate random numbers we can use the random package, a sub-package of numpy. Some usfull fuctions from this package are:
# - **seed():** sets the random seed, so that your results are reproducible between simulations. As an argument, it takes an integer of your choosing. If you call the function, no output will be generated.
# - **rand():** if you don't specify any arguments, it generates a random float between zero and one.
# - **randint():** generates random integers.

# %%
import numpy as np 
np.random.rand() # Pseudo-random numbers
# Out:
# 0.6964691855978616

# %%
# Coin toss
import numpy as np 
np.random.seed(123) # Generates random numbers based on the same seed
coin = np.random.randint(0,2) # Randomly generate 0 or 1
if coin == 0: 
    print("heads")
if coin == 1: 
    print("tails")
    # Note: the result is always 0 because we are starting from the same seed.
# Out:
# heads

# %%
import numpy as np
# Roll the dice
step = 50
dice = np.random.randint(1,7)

# Finish the control construct
if dice <= 2 :
    step = step - 1
elif dice > 2 and dice <= 5 :
    step = step + 1
else :
    step = step + np.random.randint(1,7)

# Print out dice and step
print(dice)
print(step)
# Out:
# 5
# 51

# %%
# Random Walk: to record all the random steps in a randon walk we will need to use a list and a for loop
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(123)
outcomes = []
for x in range(10) :  # range will generate a list of numbers
    coin = np.random.randint(0,2)
    if coin == 0 : 
        outcomes.append("heads")
    else : 
        outcomes.append("tails")
print(outcomes)

tails = [0]
for x in range(10) :
    coin = np.random.randint(0,2)
    tails.append(tails[x] + coin)
print(tails)

np.random.seed(123)
final_tails = []
for x in range(100) :
    tails = [0]
    for x in range(10) :
        coin = np.random.randint(0,2)
        tails.append(tails[x] + coin)
    final_tails.append(tails[-1])
print(final_tails)
plt.hist(final_tails, bins = 10)
plt.show()
# Out:
# ['heads', 'tails', 'heads', 'heads', 'heads', 'heads', 'heads', 'tails', 'tails', 'heads']
# [0, 1, 2, 2, 3, 3, 4, 4, 5, 6, 6]
# [3, 6, 4, 5, 4, 5, 3, 5, 4, 6, 6, 8, 6, 4, 7, 5, 7, 4, 3, 3, 4, 5, 8, 5, 6, 5, 7, 6, 4, 5, 8, 5, 8, 4, 6, 6, 3, 4, 5, 4, 7, 8, 9, 4, 3, 4, 5, 6, 4, 2, 6, 6, 5, 7, 5, 4, 5, 5, 6, 7, 6, 6, 6, 3, 6, 3, 6, 5, 6, 5, 6, 4, 6, 6, 3, 4, 4, 2, 4, 5, 4, 6, 6, 6, 8, 4, 6, 5, 7, 4, 6, 5, 4, 6, 7, 3, 7, 4, 5, 7]

# %%
import numpy as np
import matplotlib.pyplot as plt

# initialize and populate all_walks
all_walks = []
for i in range(20) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
            
    # Implement clumsiness
        if np.random.rand() <= 0.005 :
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to NumPy array: np_aw
np_aw = np.array(all_walks)

# Plot np_aw and show
plt.plot(np_aw)
plt.show()

# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t = np.transpose(np_aw)

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulate random walk 500 times
all_walks = []
for i in range(500) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        if np.random.rand() <= 0.001 :
            step = 0
        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
np_aw_t

# Select last row from np_aw_t: ends
ends = np_aw_t[-1,:]
ends

# Plot histogram of ends, display plot
plt.hist(ends, bins = 10)
plt.show()

# Calculate odds 
odds = ((np.count_nonzero(ends >= 60))/500)*100
odds
# Out:
# 75.8
